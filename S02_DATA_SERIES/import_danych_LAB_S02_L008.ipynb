# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import math as math

# %%
education = pd.read_csv('survey_results_public.csv', usecols= ['EdLevel'])

# %%
type(eduaction)
# Out:
# pandas.core.frame.DataFrame

# %%
education.head()
# Out:
#                                              EdLevel
# 0  Secondary school (e.g. American high school, G...
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)

# %%
education.tail(10)
# Out:
#                                                  EdLevel
# 83429       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83430    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83431       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83433       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436  Secondary school (e.g. American high school, G...
# 83437       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438                 Professional degree (JD, MD, etc.)

# %%
allinfo = pd.read_csv('survey_results_public.csv')

# %%
allinfo.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
country = allinfo['Country']

# %%
country.head()
# Out:
# 0                                             Slovakia
# 1                                          Netherlands
# 2                                   Russian Federation
# 3                                              Austria
# 4    United Kingdom of Great Britain and Northern I...
# Name: Country, dtype: object

# %%
filterOnlyUSA = country == 'United States of America'
filterOnlyUSA.head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: Country, dtype: bool

# %%
filterOnlyUSA.head()
# Out:
#    ResponseId                      MainBranch  \
# 0         1.0  I am a developer by profession
# 1         NaN                             NaN
# 2         NaN                             NaN
# 3         NaN                             NaN
# 4         NaN                             NaN
#
#                                           Employment   Country US_State  \
# 0  Independent contractor, freelancer, or self-em...  Slovakia      NaN
# 1                                                NaN       NaN      NaN
# 2                                                NaN       NaN      NaN
# 3                                                NaN       NaN      NaN
# 4                                                NaN       NaN      NaN
#
#   UK_Country                                            EdLevel  \
# 0        NaN  Secondary school (e.g. American high school, G...
# 1        NaN                                                NaN
# ...

# %%
education.where(filterOnlyUSA).dropna().tail(10)
# Out:
#                                                  EdLevel
# 83404       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83412    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83414  Secondary school (e.g. American high school, G...
# 83416       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83426       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83427       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83429       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83430    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436  Secondary school (e.g. American high school, G...
